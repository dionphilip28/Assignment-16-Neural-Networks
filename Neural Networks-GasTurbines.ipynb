# %% [markdown]
# ## Problem Statement: Predicting turbine energy yield (TEY) using ambient variables as features.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from keras.models import Sequential
from keras.layers import Dense

# %%
df = pd.read_csv('gas_turbines.csv')
df.head()
# Out:
#        AT      AP      AH    AFDP    GTEP     TIT     TAT     TEY     CDP  \
# 0  6.8594  1007.9  96.799  3.5000  19.663  1059.2  550.00  114.70  10.605
# 1  6.7850  1008.4  97.118  3.4998  19.728  1059.3  550.00  114.72  10.598
# 2  6.8977  1008.8  95.939  3.4824  19.779  1059.4  549.87  114.71  10.601
# 3  7.0569  1009.2  95.249  3.4805  19.792  1059.6  549.99  114.72  10.606
# 4  7.3978  1009.7  95.150  3.4976  19.765  1059.7  549.98  114.72  10.612
#
#        CO     NOX
# 0  3.1547  82.722
# 1  3.2363  82.776
# 2  3.2012  82.468
# 3  3.1923  82.670
# 4  3.2484  82.311

# %%
df.columns
# Out:
# Index(['AT', 'AP', 'AH', 'AFDP', 'GTEP', 'TIT', 'TAT', 'TEY', 'CDP', 'CO',
#        'NOX'],
#       dtype='object')

# %%
X = df.loc[:,['AT', 'AP', 'AH', 'AFDP', 'GTEP', 'TIT', 'TAT', 'CDP', 'CO','NOX']].values
Y = df.loc[:,['TEY']].values

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = scaler.fit_transform(X)
Y = scaler.fit_transform(Y)

# %%
X
# Out:
# array([[-1.4397781 , -0.82664395,  1.28143632, ..., -1.35733078,
#          0.53201195,  1.3878449 ],
#        [-1.44960109, -0.74864748,  1.30456402, ..., -1.36367619,
#          0.56873344,  1.39300237],
#        [-1.43472138, -0.68625031,  1.21908576, ..., -1.36095673,
#          0.5529378 ,  1.36358566],
#        ...,
#        [-1.38626659, -1.07623263,  1.47697056, ..., -1.46792219,
#          2.69592467,  2.17006209],
#        [-1.42042259, -0.99823616,  1.44159024, ..., -1.42259784,
#          1.9246834 ,  2.391165  ],
#        [-1.43073409, -0.93583899,  1.33465179, ..., -1.37727349,
#          1.35415028,  2.32153907]])

# %%
Y
# Out:
# array([[-1.23117246],
#        [-1.22990897],
#        [-1.23054071],
#        ...,
#        [-1.5160891 ],
#        [-1.48134317],
#        [-1.42827666]])

# %%
# fix random seed for reproducibility
seed = 7
np.random.seed(seed)

# %%
#Creating the model
model= Sequential()
model.add(Dense(12, input_dim = 10, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dense(8,  kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dense(1,  kernel_initializer = 'uniform', activation = 'linear'))

# %%
model.compile(loss='mse', optimizer='adam', metrics=['accuracy'])

# %%
#Fit the model
history=model.fit(X, Y, validation_split=0.33, epochs=100, batch_size=10)
# Out:
# Epoch 1/100
# 1008/1008 [==============================] - 2s 1ms/step - loss: 0.1282 - accuracy: 0.0000e+00 - val_loss: 0.0038 - val_accuracy: 0.0000e+00
# Epoch 2/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0031 - accuracy: 0.0000e+00 - val_loss: 0.0026 - val_accuracy: 0.0000e+00
# Epoch 3/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0025 - accuracy: 0.0000e+00 - val_loss: 0.0023 - val_accuracy: 0.0000e+00
# Epoch 4/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0022 - accuracy: 0.0000e+00 - val_loss: 0.0025 - val_accuracy: 0.0000e+00
# Epoch 5/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0020 - accuracy: 0.0000e+00 - val_loss: 0.0021 - val_accuracy: 0.0000e+00oss: 0.0021 - accura
# Epoch 6/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0020 - accuracy: 0.0000e+00 - val_loss: 0.0023 - val_accuracy: 0.0000e+00
# Epoch 7/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0019 - accuracy: 0.0000e+00 - val_loss: 0.0021 - val_accuracy: 0.0000e+00
# Epoch 8/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0019 - accuracy: 0.0000e+00 - val_loss: 0.0020 - val_accuracy: 0.0000e+00 - loss: 0.0019 - accuracy: 0.0000
# Epoch 9/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0019 - accuracy: 0.0000e+00 - val_loss: 0.0021 - val_accuracy: 0.0000e+00019 - accuracy: 0.0000 - ETA: 0s - loss: 0.0019 - accuracy:
# Epoch 10/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0019 - accuracy: 0.0000e+00 - val_loss: 0.0023 - val_accuracy: 0.0000e+00
# Epoch 11/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0018 - accuracy: 0.0000e+00 - val_loss: 0.0018 - val_accuracy: 0.0000e+00
# Epoch 12/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0018 - accuracy: 0.0000e+00 - val_loss: 0.0020 - val_accuracy: 0.0000e+00: 0s - loss: 0.0017 - accu
# Epoch 13/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0017 - accuracy: 0.0000e+00 - val_loss: 0.0017 - val_accuracy: 0.0000e+00
# Epoch 14/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0017 - accuracy: 0.0000e+00 - val_loss: 0.0019 - val_accuracy: 0.0000e+00
# Epoch 15/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0016 - accuracy: 0.0000e+00 - val_loss: 0.0019 - val_accuracy: 0.0000e+00: 0s - loss: 0.0017 - accuracy: 0.0000 - ETA: 0s - loss: 0.0017 -
# Epoch 16/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0016 - accuracy: 0.0000e+00 - val_loss: 0.0017 - val_accuracy: 0.0000e+00
# Epoch 17/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0016 - accuracy: 0.0000e+00 - val_loss: 0.0020 - val_accuracy: 0.0000e+00
# Epoch 18/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0015 - accuracy: 0.0000e+00 - val_loss: 0.0019 - val_accuracy: 0.0000e+00
# Epoch 19/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0015 - accuracy: 0.0000e+00 - val_loss: 0.0017 - val_accuracy: 0.0000e+00: 0s - loss: 0.0016 - accuracy:  - ETA: 0s - loss: 0.0015 - accuracy: 0.0000 - ETA: 0s - loss: 0.0015 - accura
# Epoch 20/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0015 - accuracy: 0.0000e+00 - val_loss: 0.0017 - val_accuracy: 0.0000e+00
# Epoch 21/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0015 - accuracy: 0.0000e+00 - val_loss: 0.0019 - val_accuracy: 0.0000e+000s - loss: 0.0014 - accuracy: 0.0000 - ETA: 0s - loss: 0.0015 -
# Epoch 22/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0015 - accuracy: 0.0000e+00 - val_loss: 0.0018 - val_accuracy: 0.0000e+00
# Epoch 23/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0015 - accuracy: 0.0000e+00 - val_loss: 0.0020 - val_accuracy: 0.0000e+00
# Epoch 24/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0015 - accuracy: 0.0000e+00 - val_loss: 0.0017 - val_accuracy: 0.0000e+00
# Epoch 25/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0015 - accuracy: 0.0000e+00 - val_loss: 0.0016 - val_accuracy: 0.0000e+00
# Epoch 26/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0015 - accuracy: 0.0000e+00 - val_loss: 0.0023 - val_accuracy: 0.0000e+00
# Epoch 27/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0014 - accuracy: 0.0000e+00 - val_loss: 0.0018 - val_accuracy: 0.0000e+00
# Epoch 28/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0014 - accuracy: 0.0000e+00 - val_loss: 0.0020 - val_accuracy: 0.0000e+00
# Epoch 29/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0014 - accuracy: 0.0000e+00 - val_loss: 0.0018 - val_accuracy: 0.0000e+00
# Epoch 30/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0014 - accuracy: 0.0000e+00 - val_loss: 0.0020 - val_accuracy: 0.0000e+00
# Epoch 31/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0014 - accuracy: 0.0000e+00 - val_loss: 0.0017 - val_accuracy: 0.0000e+00
# Epoch 32/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0014 - accuracy: 0.0000e+00 - val_loss: 0.0017 - val_accuracy: 0.0000e+00
# Epoch 33/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0014 - accuracy: 0.0000e+00 - val_loss: 0.0017 - val_accuracy: 0.0000e+00
# Epoch 34/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0014 - accuracy: 0.0000e+00 - val_loss: 0.0019 - val_accuracy: 0.0000e+00
# Epoch 35/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0014 - accuracy: 0.0000e+00 - val_loss: 0.0016 - val_accuracy: 0.0000e+00
# Epoch 36/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0014 - accuracy: 0.0000e+00 - val_loss: 0.0017 - val_accuracy: 0.0000e+00
# Epoch 37/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0014 - accuracy: 0.0000e+00 - val_loss: 0.0017 - val_accuracy: 0.0000e+00
# Epoch 38/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0014 - accuracy: 0.0000e+00 - val_loss: 0.0017 - val_accuracy: 0.0000e+00
# Epoch 39/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0014 - accuracy: 0.0000e+00 - val_loss: 0.0017 - val_accuracy: 0.0000e+00
# Epoch 40/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0014 - accuracy: 0.0000e+00 - val_loss: 0.0018 - val_accuracy: 0.0000e+00
# Epoch 41/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0014 - accuracy: 0.0000e+00 - val_loss: 0.0016 - val_accuracy: 0.0000e+00
# Epoch 42/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0014 - accuracy: 0.0000e+00 - val_loss: 0.0016 - val_accuracy: 0.0000e+00
# Epoch 43/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0014 - accuracy: 0.0000e+00 - val_loss: 0.0016 - val_accuracy: 0.0000e+00
# Epoch 44/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 0.0019 - val_accuracy: 0.0000e+00
# Epoch 45/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 0.0018 - val_accuracy: 0.0000e+00
# Epoch 46/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0014 - accuracy: 0.0000e+00 - val_loss: 0.0018 - val_accuracy: 0.0000e+00
# Epoch 47/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 0.0017 - val_accuracy: 0.0000e+00
# Epoch 48/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0014 - accuracy: 0.0000e+00 - val_loss: 0.0018 - val_accuracy: 0.0000e+00
# Epoch 49/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 0.0018 - val_accuracy: 0.0000e+00
# Epoch 50/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 0.0017 - val_accuracy: 0.0000e+00
# Epoch 51/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 0.0022 - val_accuracy: 0.0000e+00
# Epoch 52/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 0.0018 - val_accuracy: 0.0000e+00
# Epoch 53/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 0.0019 - val_accuracy: 0.0000e+00
# Epoch 54/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 0.0017 - val_accuracy: 0.0000e+00
# Epoch 55/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 0.0016 - val_accuracy: 0.0000e+00
# Epoch 56/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 0.0018 - val_accuracy: 0.0000e+00
# Epoch 57/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 0.0019 - val_accuracy: 0.0000e+00
# Epoch 58/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 0.0019 - val_accuracy: 0.0000e+00
# Epoch 59/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 0.0017 - val_accuracy: 0.0000e+00
# Epoch 60/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 0.0018 - val_accuracy: 0.0000e+00
# Epoch 61/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 0.0016 - val_accuracy: 0.0000e+00
# Epoch 62/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 0.0017 - val_accuracy: 0.0000e+00
# Epoch 63/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 0.0021 - val_accuracy: 0.0000e+00
# Epoch 64/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 0.0017 - val_accuracy: 0.0000e+00
# Epoch 65/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 0.0016 - val_accuracy: 0.0000e+00
# Epoch 66/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 0.0017 - val_accuracy: 0.0000e+00
# Epoch 67/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 0.0018 - val_accuracy: 0.0000e+00
# Epoch 68/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 0.0018 - val_accuracy: 0.0000e+00
# Epoch 69/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 0.0018 - val_accuracy: 0.0000e+00
# Epoch 70/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 0.0017 - val_accuracy: 0.0000e+00
# Epoch 71/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 0.0019 - val_accuracy: 0.0000e+00
# Epoch 72/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 0.0018 - val_accuracy: 0.0000e+00
# Epoch 73/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 0.0017 - val_accuracy: 0.0000e+00
# Epoch 74/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 0.0015 - val_accuracy: 0.0000e+00
# Epoch 75/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 0.0020 - val_accuracy: 0.0000e+00
# Epoch 76/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 0.0017 - val_accuracy: 0.0000e+00
# Epoch 77/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 0.0018 - val_accuracy: 0.0000e+00
# Epoch 78/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 0.0018 - val_accuracy: 0.0000e+00
# Epoch 79/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 0.0023 - val_accuracy: 0.0000e+00
# Epoch 80/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 0.0018 - val_accuracy: 0.0000e+00
# Epoch 81/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 0.0016 - val_accuracy: 0.0000e+00
# Epoch 82/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 0.0019 - val_accuracy: 0.0000e+00
# Epoch 83/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 0.0022 - val_accuracy: 0.0000e+00
# Epoch 84/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 0.0017 - val_accuracy: 0.0000e+00
# Epoch 85/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 0.0017 - val_accuracy: 0.0000e+00
# Epoch 86/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0012 - accuracy: 0.0000e+00 - val_loss: 0.0017 - val_accuracy: 0.0000e+00
# Epoch 87/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 0.0015 - val_accuracy: 0.0000e+00
# Epoch 88/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 0.0016 - val_accuracy: 0.0000e+00
# Epoch 89/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0012 - accuracy: 0.0000e+00 - val_loss: 0.0018 - val_accuracy: 0.0000e+00
# Epoch 90/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 0.0017 - val_accuracy: 0.0000e+00
# Epoch 91/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0012 - accuracy: 0.0000e+00 - val_loss: 0.0019 - val_accuracy: 0.0000e+00
# Epoch 92/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0012 - accuracy: 0.0000e+00 - val_loss: 0.0017 - val_accuracy: 0.0000e+00
# Epoch 93/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 0.0022 - val_accuracy: 0.0000e+00
# Epoch 94/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0012 - accuracy: 0.0000e+00 - val_loss: 0.0021 - val_accuracy: 0.0000e+00
# Epoch 95/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0012 - accuracy: 0.0000e+00 - val_loss: 0.0015 - val_accuracy: 0.0000e+00
# Epoch 96/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0012 - accuracy: 0.0000e+00 - val_loss: 0.0017 - val_accuracy: 0.0000e+00
# Epoch 97/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 0.0014 - val_accuracy: 0.0000e+00
# Epoch 98/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 0.0021 - val_accuracy: 0.0000e+00
# Epoch 99/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0012 - accuracy: 0.0000e+00 - val_loss: 0.0015 - val_accuracy: 0.0000e+00
# Epoch 100/100
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.0012 - accuracy: 0.0000e+00 - val_loss: 0.0019 - val_accuracy: 0.0000e+00

# %%
# evaluate the model
scores=model.evaluate(X,Y)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]* scores[1]*100))
# Out:
# 470/470 [==============================] - 0s 757us/step - loss: 0.0017 - accuracy: 0.0000e+00
# accuracy: 0.00%

# %%
#list all data in history
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Train','Test'], loc='upper left')
plt.show()

#Summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Train','Test'], loc='upper left')
plt.show()

# %% [markdown]
# ## Tuning of Hyperparameters :- Batch Size and Epochs

# %%
# Importing the necessary packages
from sklearn.model_selection import GridSearchCV, KFold
from keras.models import Sequential
from keras.layers import Dense
import tensorflow as tf
import warnings
warnings.filterwarnings("ignore")
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.metrics import classification_report, accuracy_score
from keras.layers import Dropout

# %%
# create model
def create_model():
    model = Sequential()
    model.add(Dense(12, input_dim=10, kernel_initializer='uniform', activation='relu'))
    model.add(Dense(8, kernel_initializer='uniform', activation='relu'))
    model.add(Dense(1, kernel_initializer='uniform', activation='linear'))
    
    adam = tf.keras.optimizers.Adam(lr = 0.01)
    model.compile(loss='binary_crossentropy', optimizer=adam, metrics=['accuracy'])
    return model

# %%
# Create the model
model = KerasClassifier(build_fn = create_model,verbose = 0)
# Define the grid search parameters
batch_size = [10,20,40]
epochs = [10,50,100]
# Make a dictionary of the grid search parameters
param_grid = dict(batch_size = batch_size,epochs = epochs)
# Build and fit the GridSearchCV
grid = GridSearchCV(estimator = model, param_grid = param_grid,cv = KFold(),verbose = 10)
grid_result = grid.fit(X,Y)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5; 1/9] START batch_size=10, epochs=10....................................
# [CV 1/5; 1/9] END ..................batch_size=10, epochs=10; total time=   9.7s
# [CV 2/5; 1/9] START batch_size=10, epochs=10....................................
# [CV 2/5; 1/9] END ..................batch_size=10, epochs=10; total time=  10.2s
# [CV 3/5; 1/9] START batch_size=10, epochs=10....................................
# [CV 3/5; 1/9] END ..................batch_size=10, epochs=10; total time=  10.1s
# [CV 4/5; 1/9] START batch_size=10, epochs=10....................................
# [CV 4/5; 1/9] END ..................batch_size=10, epochs=10; total time=  10.6s
# [CV 5/5; 1/9] START batch_size=10, epochs=10....................................
# [CV 5/5; 1/9] END ..................batch_size=10, epochs=10; total time=  10.1s
# [CV 1/5; 2/9] START batch_size=10, epochs=50....................................
# [CV 1/5; 2/9] END ..................batch_size=10, epochs=50; total time=  48.5s
# [CV 2/5; 2/9] START batch_size=10, epochs=50....................................
# [CV 2/5; 2/9] END ..................batch_size=10, epochs=50; total time=  43.0s
# [CV 3/5; 2/9] START batch_size=10, epochs=50....................................
# [CV 3/5; 2/9] END ..................batch_size=10, epochs=50; total time=  43.2s
# [CV 4/5; 2/9] START batch_size=10, epochs=50....................................
# [CV 4/5; 2/9] END ..................batch_size=10, epochs=50; total time=  44.6s
# [CV 5/5; 2/9] START batch_size=10, epochs=50....................................
# [CV 5/5; 2/9] END ..................batch_size=10, epochs=50; total time=  41.9s
# [CV 1/5; 3/9] START batch_size=10, epochs=100...................................
# [CV 1/5; 3/9] END .................batch_size=10, epochs=100; total time= 1.5min
# [CV 2/5; 3/9] START batch_size=10, epochs=100...................................
# [CV 2/5; 3/9] END .................batch_size=10, epochs=100; total time= 1.4min
# [CV 3/5; 3/9] START batch_size=10, epochs=100...................................
# [CV 3/5; 3/9] END .................batch_size=10, epochs=100; total time= 1.5min
# [CV 4/5; 3/9] START batch_size=10, epochs=100...................................
# [CV 4/5; 3/9] END .................batch_size=10, epochs=100; total time= 1.5min
# [CV 5/5; 3/9] START batch_size=10, epochs=100...................................
# [CV 5/5; 3/9] END .................batch_size=10, epochs=100; total time= 1.4min
# [CV 1/5; 4/9] START batch_size=20, epochs=10....................................
# [CV 1/5; 4/9] END ..................batch_size=20, epochs=10; total time=   4.8s
# [CV 2/5; 4/9] START batch_size=20, epochs=10....................................
# [CV 2/5; 4/9] END ..................batch_size=20, epochs=10; total time=   5.3s
# [CV 3/5; 4/9] START batch_size=20, epochs=10....................................
# [CV 3/5; 4/9] END ..................batch_size=20, epochs=10; total time=   4.6s
# [CV 4/5; 4/9] START batch_size=20, epochs=10....................................
# [CV 4/5; 4/9] END ..................batch_size=20, epochs=10; total time=   5.2s
# [CV 5/5; 4/9] START batch_size=20, epochs=10....................................
# [CV 5/5; 4/9] END ..................batch_size=20, epochs=10; total time=   5.2s
# [CV 1/5; 5/9] START batch_size=20, epochs=50....................................
# [CV 1/5; 5/9] END ..................batch_size=20, epochs=50; total time=  24.5s
# [CV 2/5; 5/9] START batch_size=20, epochs=50....................................
# [CV 2/5; 5/9] END ..................batch_size=20, epochs=50; total time=  24.7s
# [CV 3/5; 5/9] START batch_size=20, epochs=50....................................
# [CV 3/5; 5/9] END ..................batch_size=20, epochs=50; total time=  21.1s
# [CV 4/5; 5/9] START batch_size=20, epochs=50....................................
# [CV 4/5; 5/9] END ..................batch_size=20, epochs=50; total time=  22.5s
# [CV 5/5; 5/9] START batch_size=20, epochs=50....................................
# [CV 5/5; 5/9] END ..................batch_size=20, epochs=50; total time=  24.7s
# [CV 1/5; 6/9] START batch_size=20, epochs=100...................................
# [CV 1/5; 6/9] END .................batch_size=20, epochs=100; total time=  46.7s
# [CV 2/5; 6/9] START batch_size=20, epochs=100...................................
# [CV 2/5; 6/9] END .................batch_size=20, epochs=100; total time=  48.4s
# [CV 3/5; 6/9] START batch_size=20, epochs=100...................................
# [CV 3/5; 6/9] END .................batch_size=20, epochs=100; total time=  52.1s
# [CV 4/5; 6/9] START batch_size=20, epochs=100...................................
# [CV 4/5; 6/9] END .................batch_size=20, epochs=100; total time=  43.9s
# [CV 5/5; 6/9] START batch_size=20, epochs=100...................................
# [CV 5/5; 6/9] END .................batch_size=20, epochs=100; total time=  42.7s
# [CV 1/5; 7/9] START batch_size=40, epochs=10....................................
# [CV 1/5; 7/9] END ..................batch_size=40, epochs=10; total time=   3.1s
# [CV 2/5; 7/9] START batch_size=40, epochs=10....................................
# [CV 2/5; 7/9] END ..................batch_size=40, epochs=10; total time=   2.9s
# [CV 3/5; 7/9] START batch_size=40, epochs=10....................................
# [CV 3/5; 7/9] END ..................batch_size=40, epochs=10; total time=   2.9s
# [CV 4/5; 7/9] START batch_size=40, epochs=10....................................
# [CV 4/5; 7/9] END ..................batch_size=40, epochs=10; total time=   2.9s
# [CV 5/5; 7/9] START batch_size=40, epochs=10....................................
# [CV 5/5; 7/9] END ..................batch_size=40, epochs=10; total time=   2.9s
# [CV 1/5; 8/9] START batch_size=40, epochs=50....................................
# [CV 1/5; 8/9] END ..................batch_size=40, epochs=50; total time=  12.8s
# [CV 2/5; 8/9] START batch_size=40, epochs=50....................................
# [CV 2/5; 8/9] END ..................batch_size=40, epochs=50; total time=  12.0s
# [CV 3/5; 8/9] START batch_size=40, epochs=50....................................
# [CV 3/5; 8/9] END ..................batch_size=40, epochs=50; total time=  11.9s
# [CV 4/5; 8/9] START batch_size=40, epochs=50....................................
# [CV 4/5; 8/9] END ..................batch_size=40, epochs=50; total time=  11.6s
# [CV 5/5; 8/9] START batch_size=40, epochs=50....................................
# [CV 5/5; 8/9] END ..................batch_size=40, epochs=50; total time=  13.0s
# [CV 1/5; 9/9] START batch_size=40, epochs=100...................................
# [CV 1/5; 9/9] END .................batch_size=40, epochs=100; total time=  24.9s
# [CV 2/5; 9/9] START batch_size=40, epochs=100...................................
# [CV 2/5; 9/9] END .................batch_size=40, epochs=100; total time=  22.9s
# [CV 3/5; 9/9] START batch_size=40, epochs=100...................................
# [CV 3/5; 9/9] END .................batch_size=40, epochs=100; total time=  25.0s
# [CV 4/5; 9/9] START batch_size=40, epochs=100...................................
# [CV 4/5; 9/9] END .................batch_size=40, epochs=100; total time=  24.6s
# [CV 5/5; 9/9] START batch_size=40, epochs=100...................................
# [CV 5/5; 9/9] END .................batch_size=40, epochs=100; total time=  24.3s

# %%
# Summarize the results
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best : 0.00033255736343562603, using {'batch_size': 10, 'epochs': 50}
# 0.0,0.0 with: {'batch_size': 10, 'epochs': 10}
# 0.00033255736343562603,0.0006651147268712521 with: {'batch_size': 10, 'epochs': 50}
# 0.0,0.0 with: {'batch_size': 10, 'epochs': 100}
# 0.0,0.0 with: {'batch_size': 20, 'epochs': 10}
# 0.0,0.0 with: {'batch_size': 20, 'epochs': 50}
# 0.0,0.0 with: {'batch_size': 20, 'epochs': 100}
# 0.0,0.0 with: {'batch_size': 40, 'epochs': 10}
# 0.0,0.0 with: {'batch_size': 40, 'epochs': 50}
# 0.0,0.0 with: {'batch_size': 40, 'epochs': 100}

# %% [markdown]
# ### Tuning of Hyperparameters:- Learning rate and Drop out rate

# %%
from keras.layers import Dropout

# Defining the model

def create_model(learning_rate,dropout_rate):
    model = Sequential()
    model.add(Dense(8,input_dim = 10,kernel_initializer = 'normal',activation = 'relu'))
    model.add(Dropout(dropout_rate))
    model.add(Dense(4,input_dim = 10,kernel_initializer = 'normal',activation = 'relu'))
    model.add(Dropout(dropout_rate))
    model.add(Dense(1,activation = 'linear'))
    
    adam = tf.keras.optimizers.Adam(lr = learning_rate)
    model.compile(loss = 'binary_crossentropy',optimizer = adam,metrics = ['accuracy'])
    return model

# Create the model

model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)

# Define the grid search parameters

learning_rate = [0.001,0.01,0.1]
dropout_rate = [0.0,0.1,0.2]

# Make a dictionary of the grid search parameters

param_grids = dict(learning_rate = learning_rate,dropout_rate = dropout_rate)

# Build and fit the GridSearchCV

grid = GridSearchCV(estimator = model,param_grid = param_grids,cv = KFold(),verbose = 10)
grid_result = grid.fit(X,Y)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5; 1/9] START dropout_rate=0.0, learning_rate=0.001.......................
# [CV 1/5; 1/9] END .....dropout_rate=0.0, learning_rate=0.001; total time=   2.8s
# [CV 2/5; 1/9] START dropout_rate=0.0, learning_rate=0.001.......................
# [CV 2/5; 1/9] END .....dropout_rate=0.0, learning_rate=0.001; total time=   3.0s
# [CV 3/5; 1/9] START dropout_rate=0.0, learning_rate=0.001.......................
# [CV 3/5; 1/9] END .....dropout_rate=0.0, learning_rate=0.001; total time=   2.6s
# [CV 4/5; 1/9] START dropout_rate=0.0, learning_rate=0.001.......................
# [CV 4/5; 1/9] END .....dropout_rate=0.0, learning_rate=0.001; total time=   2.7s
# [CV 5/5; 1/9] START dropout_rate=0.0, learning_rate=0.001.......................
# [CV 5/5; 1/9] END .....dropout_rate=0.0, learning_rate=0.001; total time=   2.8s
# [CV 1/5; 2/9] START dropout_rate=0.0, learning_rate=0.01........................
# [CV 1/5; 2/9] END ......dropout_rate=0.0, learning_rate=0.01; total time=   3.1s
# [CV 2/5; 2/9] START dropout_rate=0.0, learning_rate=0.01........................
# [CV 2/5; 2/9] END ......dropout_rate=0.0, learning_rate=0.01; total time=   3.3s
# [CV 3/5; 2/9] START dropout_rate=0.0, learning_rate=0.01........................
# [CV 3/5; 2/9] END ......dropout_rate=0.0, learning_rate=0.01; total time=   3.2s
# [CV 4/5; 2/9] START dropout_rate=0.0, learning_rate=0.01........................
# [CV 4/5; 2/9] END ......dropout_rate=0.0, learning_rate=0.01; total time=   3.8s
# [CV 5/5; 2/9] START dropout_rate=0.0, learning_rate=0.01........................
# [CV 5/5; 2/9] END ......dropout_rate=0.0, learning_rate=0.01; total time=   3.0s
# [CV 1/5; 3/9] START dropout_rate=0.0, learning_rate=0.1.........................
# [CV 1/5; 3/9] END .......dropout_rate=0.0, learning_rate=0.1; total time=   3.1s
# [CV 2/5; 3/9] START dropout_rate=0.0, learning_rate=0.1.........................
# [CV 2/5; 3/9] END .......dropout_rate=0.0, learning_rate=0.1; total time=   3.2s
# [CV 3/5; 3/9] START dropout_rate=0.0, learning_rate=0.1.........................
# [CV 3/5; 3/9] END .......dropout_rate=0.0, learning_rate=0.1; total time=   3.2s
# [CV 4/5; 3/9] START dropout_rate=0.0, learning_rate=0.1.........................
# [CV 4/5; 3/9] END .......dropout_rate=0.0, learning_rate=0.1; total time=   2.6s
# [CV 5/5; 3/9] START dropout_rate=0.0, learning_rate=0.1.........................
# [CV 5/5; 3/9] END .......dropout_rate=0.0, learning_rate=0.1; total time=   3.0s
# [CV 1/5; 4/9] START dropout_rate=0.1, learning_rate=0.001.......................
# [CV 1/5; 4/9] END .....dropout_rate=0.1, learning_rate=0.001; total time=   4.1s
# [CV 2/5; 4/9] START dropout_rate=0.1, learning_rate=0.001.......................
# [CV 2/5; 4/9] END .....dropout_rate=0.1, learning_rate=0.001; total time=   3.1s
# [CV 3/5; 4/9] START dropout_rate=0.1, learning_rate=0.001.......................
# [CV 3/5; 4/9] END .....dropout_rate=0.1, learning_rate=0.001; total time=   3.3s
# [CV 4/5; 4/9] START dropout_rate=0.1, learning_rate=0.001.......................
# [CV 4/5; 4/9] END .....dropout_rate=0.1, learning_rate=0.001; total time=   3.2s
# [CV 5/5; 4/9] START dropout_rate=0.1, learning_rate=0.001.......................
# [CV 5/5; 4/9] END .....dropout_rate=0.1, learning_rate=0.001; total time=   3.1s
# [CV 1/5; 5/9] START dropout_rate=0.1, learning_rate=0.01........................
# [CV 1/5; 5/9] END ......dropout_rate=0.1, learning_rate=0.01; total time=   3.8s
# [CV 2/5; 5/9] START dropout_rate=0.1, learning_rate=0.01........................
# [CV 2/5; 5/9] END ......dropout_rate=0.1, learning_rate=0.01; total time=   4.0s
# [CV 3/5; 5/9] START dropout_rate=0.1, learning_rate=0.01........................
# [CV 3/5; 5/9] END ......dropout_rate=0.1, learning_rate=0.01; total time=   3.0s
# [CV 4/5; 5/9] START dropout_rate=0.1, learning_rate=0.01........................
# [CV 4/5; 5/9] END ......dropout_rate=0.1, learning_rate=0.01; total time=   2.9s
# [CV 5/5; 5/9] START dropout_rate=0.1, learning_rate=0.01........................
# [CV 5/5; 5/9] END ......dropout_rate=0.1, learning_rate=0.01; total time=   3.1s
# [CV 1/5; 6/9] START dropout_rate=0.1, learning_rate=0.1.........................
# [CV 1/5; 6/9] END .......dropout_rate=0.1, learning_rate=0.1; total time=   3.0s
# [CV 2/5; 6/9] START dropout_rate=0.1, learning_rate=0.1.........................
# [CV 2/5; 6/9] END .......dropout_rate=0.1, learning_rate=0.1; total time=   3.9s
# [CV 3/5; 6/9] START dropout_rate=0.1, learning_rate=0.1.........................
# [CV 3/5; 6/9] END .......dropout_rate=0.1, learning_rate=0.1; total time=   4.0s
# [CV 4/5; 6/9] START dropout_rate=0.1, learning_rate=0.1.........................
# [CV 4/5; 6/9] END .......dropout_rate=0.1, learning_rate=0.1; total time=   3.1s
# [CV 5/5; 6/9] START dropout_rate=0.1, learning_rate=0.1.........................
# [CV 5/5; 6/9] END .......dropout_rate=0.1, learning_rate=0.1; total time=   3.1s
# [CV 1/5; 7/9] START dropout_rate=0.2, learning_rate=0.001.......................
# [CV 1/5; 7/9] END .....dropout_rate=0.2, learning_rate=0.001; total time=   3.2s
# [CV 2/5; 7/9] START dropout_rate=0.2, learning_rate=0.001.......................
# [CV 2/5; 7/9] END .....dropout_rate=0.2, learning_rate=0.001; total time=   3.7s
# [CV 3/5; 7/9] START dropout_rate=0.2, learning_rate=0.001.......................
# [CV 3/5; 7/9] END .....dropout_rate=0.2, learning_rate=0.001; total time=   4.0s
# [CV 4/5; 7/9] START dropout_rate=0.2, learning_rate=0.001.......................
# [CV 4/5; 7/9] END .....dropout_rate=0.2, learning_rate=0.001; total time=   3.3s
# [CV 5/5; 7/9] START dropout_rate=0.2, learning_rate=0.001.......................
# [CV 5/5; 7/9] END .....dropout_rate=0.2, learning_rate=0.001; total time=   4.4s
# [CV 1/5; 8/9] START dropout_rate=0.2, learning_rate=0.01........................
# [CV 1/5; 8/9] END ......dropout_rate=0.2, learning_rate=0.01; total time=   3.5s
# [CV 2/5; 8/9] START dropout_rate=0.2, learning_rate=0.01........................
# [CV 2/5; 8/9] END ......dropout_rate=0.2, learning_rate=0.01; total time=   3.8s
# [CV 3/5; 8/9] START dropout_rate=0.2, learning_rate=0.01........................
# [CV 3/5; 8/9] END ......dropout_rate=0.2, learning_rate=0.01; total time=   3.0s
# [CV 4/5; 8/9] START dropout_rate=0.2, learning_rate=0.01........................
# [CV 4/5; 8/9] END ......dropout_rate=0.2, learning_rate=0.01; total time=   3.8s
# [CV 5/5; 8/9] START dropout_rate=0.2, learning_rate=0.01........................
# [CV 5/5; 8/9] END ......dropout_rate=0.2, learning_rate=0.01; total time=   3.5s
# [CV 1/5; 9/9] START dropout_rate=0.2, learning_rate=0.1.........................
# [CV 1/5; 9/9] END .......dropout_rate=0.2, learning_rate=0.1; total time=   3.0s
# [CV 2/5; 9/9] START dropout_rate=0.2, learning_rate=0.1.........................
# [CV 2/5; 9/9] END .......dropout_rate=0.2, learning_rate=0.1; total time=   3.1s
# [CV 3/5; 9/9] START dropout_rate=0.2, learning_rate=0.1.........................
# [CV 3/5; 9/9] END .......dropout_rate=0.2, learning_rate=0.1; total time=   3.1s
# [CV 4/5; 9/9] START dropout_rate=0.2, learning_rate=0.1.........................
# [CV 4/5; 9/9] END .......dropout_rate=0.2, learning_rate=0.1; total time=   4.2s
# [CV 5/5; 9/9] START dropout_rate=0.2, learning_rate=0.1.........................
# [CV 5/5; 9/9] END .......dropout_rate=0.2, learning_rate=0.1; total time=   3.3s

# %%
# Summarize the results
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best : 0.0, using {'dropout_rate': 0.0, 'learning_rate': 0.001}
# 0.0,0.0 with: {'dropout_rate': 0.0, 'learning_rate': 0.001}
# 0.0,0.0 with: {'dropout_rate': 0.0, 'learning_rate': 0.01}
# 0.0,0.0 with: {'dropout_rate': 0.0, 'learning_rate': 0.1}
# 0.0,0.0 with: {'dropout_rate': 0.1, 'learning_rate': 0.001}
# 0.0,0.0 with: {'dropout_rate': 0.1, 'learning_rate': 0.01}
# 0.0,0.0 with: {'dropout_rate': 0.1, 'learning_rate': 0.1}
# 0.0,0.0 with: {'dropout_rate': 0.2, 'learning_rate': 0.001}
# 0.0,0.0 with: {'dropout_rate': 0.2, 'learning_rate': 0.01}
# 0.0,0.0 with: {'dropout_rate': 0.2, 'learning_rate': 0.1}

# %% [markdown]
# ### Tuning of Hyperparameters:- Activation Function and Kernel Initializer

# %%
# Defining the model

def create_model(activation_function,init):
    model = Sequential()
    model.add(Dense(8,input_dim = 10,kernel_initializer = init,activation = activation_function))
    model.add(Dropout(0.1))
    model.add(Dense(4,input_dim = 10,kernel_initializer = init,activation = activation_function))
    model.add(Dropout(0.1))
    model.add(Dense(1,activation = 'sigmoid'))
    
    adam = tf.keras.optimizers.Adam(lr = 0.001)
    model.compile(loss = 'binary_crossentropy',optimizer = adam,metrics = ['accuracy'])
    return model

# Create the model

model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)

# Define the grid search parameters
activation_function = ['softmax','relu','tanh','linear']
init = ['uniform','normal','zero']

# Make a dictionary of the grid search parameters
param_grids = dict(activation_function = activation_function,init = init)

# Build and fit the GridSearchCV

grid = GridSearchCV(estimator = model,param_grid = param_grids,cv = KFold(),verbose = 10)
grid_result = grid.fit(X,Y)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV 1/5; 1/12] START activation_function=softmax, init=uniform..................
# [CV 1/5; 1/12] END activation_function=softmax, init=uniform; total time=   3.2s
# [CV 2/5; 1/12] START activation_function=softmax, init=uniform..................
# [CV 2/5; 1/12] END activation_function=softmax, init=uniform; total time=   3.5s
# [CV 3/5; 1/12] START activation_function=softmax, init=uniform..................
# [CV 3/5; 1/12] END activation_function=softmax, init=uniform; total time=   3.1s
# [CV 4/5; 1/12] START activation_function=softmax, init=uniform..................
# [CV 4/5; 1/12] END activation_function=softmax, init=uniform; total time=   2.9s
# [CV 5/5; 1/12] START activation_function=softmax, init=uniform..................
# [CV 5/5; 1/12] END activation_function=softmax, init=uniform; total time=   3.4s
# [CV 1/5; 2/12] START activation_function=softmax, init=normal...................
# [CV 1/5; 2/12] END .activation_function=softmax, init=normal; total time=   3.1s
# [CV 2/5; 2/12] START activation_function=softmax, init=normal...................
# [CV 2/5; 2/12] END .activation_function=softmax, init=normal; total time=   3.2s
# [CV 3/5; 2/12] START activation_function=softmax, init=normal...................
# [CV 3/5; 2/12] END .activation_function=softmax, init=normal; total time=   3.1s
# [CV 4/5; 2/12] START activation_function=softmax, init=normal...................
# [CV 4/5; 2/12] END .activation_function=softmax, init=normal; total time=   3.1s
# [CV 5/5; 2/12] START activation_function=softmax, init=normal...................
# [CV 5/5; 2/12] END .activation_function=softmax, init=normal; total time=   2.9s
# [CV 1/5; 3/12] START activation_function=softmax, init=zero.....................
# [CV 1/5; 3/12] END ...activation_function=softmax, init=zero; total time=   3.3s
# [CV 2/5; 3/12] START activation_function=softmax, init=zero.....................
# [CV 2/5; 3/12] END ...activation_function=softmax, init=zero; total time=   3.3s
# [CV 3/5; 3/12] START activation_function=softmax, init=zero.....................
# [CV 3/5; 3/12] END ...activation_function=softmax, init=zero; total time=   3.4s
# [CV 4/5; 3/12] START activation_function=softmax, init=zero.....................
# [CV 4/5; 3/12] END ...activation_function=softmax, init=zero; total time=   3.4s
# [CV 5/5; 3/12] START activation_function=softmax, init=zero.....................
# [CV 5/5; 3/12] END ...activation_function=softmax, init=zero; total time=   3.3s
# [CV 1/5; 4/12] START activation_function=relu, init=uniform.....................
# [CV 1/5; 4/12] END ...activation_function=relu, init=uniform; total time=   3.0s
# [CV 2/5; 4/12] START activation_function=relu, init=uniform.....................
# [CV 2/5; 4/12] END ...activation_function=relu, init=uniform; total time=   3.1s
# [CV 3/5; 4/12] START activation_function=relu, init=uniform.....................
# [CV 3/5; 4/12] END ...activation_function=relu, init=uniform; total time=   3.0s
# [CV 4/5; 4/12] START activation_function=relu, init=uniform.....................
# [CV 4/5; 4/12] END ...activation_function=relu, init=uniform; total time=   4.1s
# [CV 5/5; 4/12] START activation_function=relu, init=uniform.....................
# [CV 5/5; 4/12] END ...activation_function=relu, init=uniform; total time=   4.0s
# [CV 1/5; 5/12] START activation_function=relu, init=normal......................
# [CV 1/5; 5/12] END ....activation_function=relu, init=normal; total time=   3.6s
# [CV 2/5; 5/12] START activation_function=relu, init=normal......................
# [CV 2/5; 5/12] END ....activation_function=relu, init=normal; total time=   3.2s
# [CV 3/5; 5/12] START activation_function=relu, init=normal......................
# [CV 3/5; 5/12] END ....activation_function=relu, init=normal; total time=   3.0s
# [CV 4/5; 5/12] START activation_function=relu, init=normal......................
# [CV 4/5; 5/12] END ....activation_function=relu, init=normal; total time=   3.3s
# [CV 5/5; 5/12] START activation_function=relu, init=normal......................
# [CV 5/5; 5/12] END ....activation_function=relu, init=normal; total time=   3.6s
# [CV 1/5; 6/12] START activation_function=relu, init=zero........................
# [CV 1/5; 6/12] END ......activation_function=relu, init=zero; total time=   3.3s
# [CV 2/5; 6/12] START activation_function=relu, init=zero........................
# [CV 2/5; 6/12] END ......activation_function=relu, init=zero; total time=   3.3s
# [CV 3/5; 6/12] START activation_function=relu, init=zero........................
# [CV 3/5; 6/12] END ......activation_function=relu, init=zero; total time=   3.0s
# [CV 4/5; 6/12] START activation_function=relu, init=zero........................
# [CV 4/5; 6/12] END ......activation_function=relu, init=zero; total time=   3.0s
# [CV 5/5; 6/12] START activation_function=relu, init=zero........................
# [CV 5/5; 6/12] END ......activation_function=relu, init=zero; total time=   2.9s
# [CV 1/5; 7/12] START activation_function=tanh, init=uniform.....................
# [CV 1/5; 7/12] END ...activation_function=tanh, init=uniform; total time=   3.0s
# [CV 2/5; 7/12] START activation_function=tanh, init=uniform.....................
# [CV 2/5; 7/12] END ...activation_function=tanh, init=uniform; total time=   2.9s
# [CV 3/5; 7/12] START activation_function=tanh, init=uniform.....................
# [CV 3/5; 7/12] END ...activation_function=tanh, init=uniform; total time=   3.0s
# [CV 4/5; 7/12] START activation_function=tanh, init=uniform.....................
# [CV 4/5; 7/12] END ...activation_function=tanh, init=uniform; total time=   3.1s
# [CV 5/5; 7/12] START activation_function=tanh, init=uniform.....................
# [CV 5/5; 7/12] END ...activation_function=tanh, init=uniform; total time=   3.3s
# [CV 1/5; 8/12] START activation_function=tanh, init=normal......................
# [CV 1/5; 8/12] END ....activation_function=tanh, init=normal; total time=   2.9s
# [CV 2/5; 8/12] START activation_function=tanh, init=normal......................
# [CV 2/5; 8/12] END ....activation_function=tanh, init=normal; total time=   2.9s
# [CV 3/5; 8/12] START activation_function=tanh, init=normal......................
# [CV 3/5; 8/12] END ....activation_function=tanh, init=normal; total time=   3.1s
# [CV 4/5; 8/12] START activation_function=tanh, init=normal......................
# [CV 4/5; 8/12] END ....activation_function=tanh, init=normal; total time=   3.0s
# [CV 5/5; 8/12] START activation_function=tanh, init=normal......................
# [CV 5/5; 8/12] END ....activation_function=tanh, init=normal; total time=   3.2s
# [CV 1/5; 9/12] START activation_function=tanh, init=zero........................
# [CV 1/5; 9/12] END ......activation_function=tanh, init=zero; total time=   3.3s
# [CV 2/5; 9/12] START activation_function=tanh, init=zero........................
# [CV 2/5; 9/12] END ......activation_function=tanh, init=zero; total time=   3.2s
# [CV 3/5; 9/12] START activation_function=tanh, init=zero........................
# [CV 3/5; 9/12] END ......activation_function=tanh, init=zero; total time=   2.7s
# [CV 4/5; 9/12] START activation_function=tanh, init=zero........................
# [CV 4/5; 9/12] END ......activation_function=tanh, init=zero; total time=   2.9s
# [CV 5/5; 9/12] START activation_function=tanh, init=zero........................
# [CV 5/5; 9/12] END ......activation_function=tanh, init=zero; total time=   3.0s
# [CV 1/5; 10/12] START activation_function=linear, init=uniform..................
# [CV 1/5; 10/12] END activation_function=linear, init=uniform; total time=   2.9s
# [CV 2/5; 10/12] START activation_function=linear, init=uniform..................
# [CV 2/5; 10/12] END activation_function=linear, init=uniform; total time=   2.8s
# [CV 3/5; 10/12] START activation_function=linear, init=uniform..................
# [CV 3/5; 10/12] END activation_function=linear, init=uniform; total time=   3.1s
# [CV 4/5; 10/12] START activation_function=linear, init=uniform..................
# [CV 4/5; 10/12] END activation_function=linear, init=uniform; total time=   3.0s
# [CV 5/5; 10/12] START activation_function=linear, init=uniform..................
# [CV 5/5; 10/12] END activation_function=linear, init=uniform; total time=   2.9s
# [CV 1/5; 11/12] START activation_function=linear, init=normal...................
# [CV 1/5; 11/12] END .activation_function=linear, init=normal; total time=   3.0s
# [CV 2/5; 11/12] START activation_function=linear, init=normal...................
# [CV 2/5; 11/12] END .activation_function=linear, init=normal; total time=   2.8s
# [CV 3/5; 11/12] START activation_function=linear, init=normal...................
# [CV 3/5; 11/12] END .activation_function=linear, init=normal; total time=   2.8s
# [CV 4/5; 11/12] START activation_function=linear, init=normal...................
# [CV 4/5; 11/12] END .activation_function=linear, init=normal; total time=   2.7s
# [CV 5/5; 11/12] START activation_function=linear, init=normal...................
# [CV 5/5; 11/12] END .activation_function=linear, init=normal; total time=   2.8s
# [CV 1/5; 12/12] START activation_function=linear, init=zero.....................
# [CV 1/5; 12/12] END ...activation_function=linear, init=zero; total time=   2.9s
# [CV 2/5; 12/12] START activation_function=linear, init=zero.....................
# [CV 2/5; 12/12] END ...activation_function=linear, init=zero; total time=   3.2s
# [CV 3/5; 12/12] START activation_function=linear, init=zero.....................
# [CV 3/5; 12/12] END ...activation_function=linear, init=zero; total time=   3.2s
# [CV 4/5; 12/12] START activation_function=linear, init=zero.....................
# [CV 4/5; 12/12] END ...activation_function=linear, init=zero; total time=   2.9s
# [CV 5/5; 12/12] START activation_function=linear, init=zero.....................
# [CV 5/5; 12/12] END ...activation_function=linear, init=zero; total time=   2.6s

# %%
# Summarize the results
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best : 0.00033255736343562603, using {'activation_function': 'linear', 'init': 'uniform'}
# 0.0,0.0 with: {'activation_function': 'softmax', 'init': 'uniform'}
# 0.0,0.0 with: {'activation_function': 'softmax', 'init': 'normal'}
# 0.0,0.0 with: {'activation_function': 'softmax', 'init': 'zero'}
# 0.0,0.0 with: {'activation_function': 'relu', 'init': 'uniform'}
# 0.0,0.0 with: {'activation_function': 'relu', 'init': 'normal'}
# 0.0,0.0 with: {'activation_function': 'relu', 'init': 'zero'}
# 0.0,0.0 with: {'activation_function': 'tanh', 'init': 'uniform'}
# 0.0,0.0 with: {'activation_function': 'tanh', 'init': 'normal'}
# 0.0,0.0 with: {'activation_function': 'tanh', 'init': 'zero'}
# 0.00033255736343562603,0.0006651147268712521 with: {'activation_function': 'linear', 'init': 'uniform'}
# 0.00033255736343562603,0.0006651147268712521 with: {'activation_function': 'linear', 'init': 'normal'}
# 0.0,0.0 with: {'activation_function': 'linear', 'init': 'zero'}

# %% [markdown]
# ### Tuning of Hyperparameter :-Number of Neurons in activation layer

# %%
# Defining the model

def create_model(neuron1,neuron2):
    model = Sequential()
    model.add(Dense(neuron1,input_dim = 10,kernel_initializer = 'uniform',activation = 'relu'))
    model.add(Dropout(0.1))
    model.add(Dense(neuron2,input_dim = neuron1,kernel_initializer = 'uniform',activation = 'relu'))
    model.add(Dropout(0.1))
    model.add(Dense(1,activation = 'linear'))
    
    adam = tf.keras.optimizers.Adam(lr = 0.001)
    model.compile(loss = 'mse',optimizer = adam,metrics = ['accuracy'])
    return model

# Create the model

model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)

# Define the grid search parameters

neuron1 = [4,8,16]
neuron2 = [2,4,8]

# Make a dictionary of the grid search parameters

param_grids = dict(neuron1 = neuron1,neuron2 = neuron2)

# Build and fit the GridSearchCV

grid = GridSearchCV(estimator = model,param_grid = param_grids,cv = KFold(),verbose = 10)
grid_result = grid.fit(X,Y)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5; 1/9] START neuron1=4, neuron2=2........................................
# [CV 1/5; 1/9] END ......................neuron1=4, neuron2=2; total time=   2.7s
# [CV 2/5; 1/9] START neuron1=4, neuron2=2........................................
# [CV 2/5; 1/9] END ......................neuron1=4, neuron2=2; total time=   2.5s
# [CV 3/5; 1/9] START neuron1=4, neuron2=2........................................
# [CV 3/5; 1/9] END ......................neuron1=4, neuron2=2; total time=   2.7s
# [CV 4/5; 1/9] START neuron1=4, neuron2=2........................................
# [CV 4/5; 1/9] END ......................neuron1=4, neuron2=2; total time=   2.7s
# [CV 5/5; 1/9] START neuron1=4, neuron2=2........................................
# [CV 5/5; 1/9] END ......................neuron1=4, neuron2=2; total time=   2.7s
# [CV 1/5; 2/9] START neuron1=4, neuron2=4........................................
# [CV 1/5; 2/9] END ......................neuron1=4, neuron2=4; total time=   2.9s
# [CV 2/5; 2/9] START neuron1=4, neuron2=4........................................
# [CV 2/5; 2/9] END ......................neuron1=4, neuron2=4; total time=   2.5s
# [CV 3/5; 2/9] START neuron1=4, neuron2=4........................................
# [CV 3/5; 2/9] END ......................neuron1=4, neuron2=4; total time=   2.7s
# [CV 4/5; 2/9] START neuron1=4, neuron2=4........................................
# [CV 4/5; 2/9] END ......................neuron1=4, neuron2=4; total time=   2.7s
# [CV 5/5; 2/9] START neuron1=4, neuron2=4........................................
# [CV 5/5; 2/9] END ......................neuron1=4, neuron2=4; total time=   3.3s
# [CV 1/5; 3/9] START neuron1=4, neuron2=8........................................
# [CV 1/5; 3/9] END ......................neuron1=4, neuron2=8; total time=   2.8s
# [CV 2/5; 3/9] START neuron1=4, neuron2=8........................................
# [CV 2/5; 3/9] END ......................neuron1=4, neuron2=8; total time=   3.0s
# [CV 3/5; 3/9] START neuron1=4, neuron2=8........................................
# [CV 3/5; 3/9] END ......................neuron1=4, neuron2=8; total time=   3.1s
# [CV 4/5; 3/9] START neuron1=4, neuron2=8........................................
# [CV 4/5; 3/9] END ......................neuron1=4, neuron2=8; total time=   2.8s
# [CV 5/5; 3/9] START neuron1=4, neuron2=8........................................
# [CV 5/5; 3/9] END ......................neuron1=4, neuron2=8; total time=   2.9s
# [CV 1/5; 4/9] START neuron1=8, neuron2=2........................................
# [CV 1/5; 4/9] END ......................neuron1=8, neuron2=2; total time=   2.8s
# [CV 2/5; 4/9] START neuron1=8, neuron2=2........................................
# [CV 2/5; 4/9] END ......................neuron1=8, neuron2=2; total time=   2.7s
# [CV 3/5; 4/9] START neuron1=8, neuron2=2........................................
# [CV 3/5; 4/9] END ......................neuron1=8, neuron2=2; total time=   3.3s
# [CV 4/5; 4/9] START neuron1=8, neuron2=2........................................
# [CV 4/5; 4/9] END ......................neuron1=8, neuron2=2; total time=   2.8s
# [CV 5/5; 4/9] START neuron1=8, neuron2=2........................................
# [CV 5/5; 4/9] END ......................neuron1=8, neuron2=2; total time=   2.6s
# [CV 1/5; 5/9] START neuron1=8, neuron2=4........................................
# [CV 1/5; 5/9] END ......................neuron1=8, neuron2=4; total time=   2.6s
# [CV 2/5; 5/9] START neuron1=8, neuron2=4........................................
# [CV 2/5; 5/9] END ......................neuron1=8, neuron2=4; total time=   2.7s
# [CV 3/5; 5/9] START neuron1=8, neuron2=4........................................
# [CV 3/5; 5/9] END ......................neuron1=8, neuron2=4; total time=   2.8s
# [CV 4/5; 5/9] START neuron1=8, neuron2=4........................................
# [CV 4/5; 5/9] END ......................neuron1=8, neuron2=4; total time=   2.7s
# [CV 5/5; 5/9] START neuron1=8, neuron2=4........................................
# [CV 5/5; 5/9] END ......................neuron1=8, neuron2=4; total time=   2.6s
# [CV 1/5; 6/9] START neuron1=8, neuron2=8........................................
# [CV 1/5; 6/9] END ......................neuron1=8, neuron2=8; total time=   2.8s
# [CV 2/5; 6/9] START neuron1=8, neuron2=8........................................
# [CV 2/5; 6/9] END ......................neuron1=8, neuron2=8; total time=   2.6s
# [CV 3/5; 6/9] START neuron1=8, neuron2=8........................................
# [CV 3/5; 6/9] END ......................neuron1=8, neuron2=8; total time=   2.6s
# [CV 4/5; 6/9] START neuron1=8, neuron2=8........................................
# [CV 4/5; 6/9] END ......................neuron1=8, neuron2=8; total time=   2.6s
# [CV 5/5; 6/9] START neuron1=8, neuron2=8........................................
# [CV 5/5; 6/9] END ......................neuron1=8, neuron2=8; total time=   2.7s
# [CV 1/5; 7/9] START neuron1=16, neuron2=2.......................................
# [CV 1/5; 7/9] END .....................neuron1=16, neuron2=2; total time=   2.6s
# [CV 2/5; 7/9] START neuron1=16, neuron2=2.......................................
# [CV 2/5; 7/9] END .....................neuron1=16, neuron2=2; total time=   2.7s
# [CV 3/5; 7/9] START neuron1=16, neuron2=2.......................................
# [CV 3/5; 7/9] END .....................neuron1=16, neuron2=2; total time=   2.8s
# [CV 4/5; 7/9] START neuron1=16, neuron2=2.......................................
# [CV 4/5; 7/9] END .....................neuron1=16, neuron2=2; total time=   2.7s
# [CV 5/5; 7/9] START neuron1=16, neuron2=2.......................................
# [CV 5/5; 7/9] END .....................neuron1=16, neuron2=2; total time=   2.6s
# [CV 1/5; 8/9] START neuron1=16, neuron2=4.......................................
# [CV 1/5; 8/9] END .....................neuron1=16, neuron2=4; total time=   2.8s
# [CV 2/5; 8/9] START neuron1=16, neuron2=4.......................................
# [CV 2/5; 8/9] END .....................neuron1=16, neuron2=4; total time=   2.8s
# [CV 3/5; 8/9] START neuron1=16, neuron2=4.......................................
# [CV 3/5; 8/9] END .....................neuron1=16, neuron2=4; total time=   2.8s
# [CV 4/5; 8/9] START neuron1=16, neuron2=4.......................................
# [CV 4/5; 8/9] END .....................neuron1=16, neuron2=4; total time=   2.9s
# [CV 5/5; 8/9] START neuron1=16, neuron2=4.......................................
# [CV 5/5; 8/9] END .....................neuron1=16, neuron2=4; total time=   2.8s
# [CV 1/5; 9/9] START neuron1=16, neuron2=8.......................................
# [CV 1/5; 9/9] END .....................neuron1=16, neuron2=8; total time=   2.9s
# [CV 2/5; 9/9] START neuron1=16, neuron2=8.......................................
# [CV 2/5; 9/9] END .....................neuron1=16, neuron2=8; total time=   3.0s
# [CV 3/5; 9/9] START neuron1=16, neuron2=8.......................................
# [CV 3/5; 9/9] END .....................neuron1=16, neuron2=8; total time=   2.8s
# [CV 4/5; 9/9] START neuron1=16, neuron2=8.......................................
# [CV 4/5; 9/9] END .....................neuron1=16, neuron2=8; total time=   3.0s
# [CV 5/5; 9/9] START neuron1=16, neuron2=8.......................................
# [CV 5/5; 9/9] END .....................neuron1=16, neuron2=8; total time=   3.4s

# %%
# Summarize the results
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best : 0.0, using {'neuron1': 4, 'neuron2': 2}
# 0.0,0.0 with: {'neuron1': 4, 'neuron2': 2}
# 0.0,0.0 with: {'neuron1': 4, 'neuron2': 4}
# 0.0,0.0 with: {'neuron1': 4, 'neuron2': 8}
# 0.0,0.0 with: {'neuron1': 8, 'neuron2': 2}
# 0.0,0.0 with: {'neuron1': 8, 'neuron2': 4}
# 0.0,0.0 with: {'neuron1': 8, 'neuron2': 8}
# 0.0,0.0 with: {'neuron1': 16, 'neuron2': 2}
# 0.0,0.0 with: {'neuron1': 16, 'neuron2': 4}
# 0.0,0.0 with: {'neuron1': 16, 'neuron2': 8}

# %% [markdown]
# ### Training model with optimum values of Hyperparameters

# %%
from sklearn.metrics import classification_report, accuracy_score
def create_model():
    model = Sequential()
    model.add(Dense(16,input_dim = 10,kernel_initializer = 'normal',activation = 'relu'))
    model.add(Dropout(0.1))
    model.add(Dense(8,input_dim = 10,kernel_initializer = 'normal',activation = 'relu'))
    model.add(Dropout(0.1))
    model.add(Dense(1,activation = 'linear'))
    
    adam = tf.keras.optimizers.Adam(lr = 0.01) #sgd = SGD(lr=learning_rate, momentum=momentum, decay=decay_rate, nesterov=False)
    model.compile(loss = 'mse',optimizer = adam,metrics = ['accuracy'])
    return model

# %%
model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 100)

# Fitting the model

model.fit(X,Y)

# Predicting using trained model

y_predict = model.predict(X)

# Printing the metrics
print(accuracy_score(y_predict.round(),Y.round()))
# Out:
# 0.06316909368974001
